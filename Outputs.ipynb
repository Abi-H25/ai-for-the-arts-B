# %% [markdown]
# **<h2>Outputs</h2>**
#
# **This notebook presents the final AI generated outputs, including the historical and modern character profiles and the enhanced hand drawn illustrations.**

# %% [markdown]
# **Wealthy Businessman Profile**
#
# Below is the initial prompt and the refinements, as well as the final text output generated for the wealthy businessman character.
#
# Initial Prompt:
#
# “Generate a short, historically accurate day in the life, styled diary entry of a 19th century, wealthy businessman travelling through Nice in 1867.”
#
# Initial Output:

# %%
from IPython.display import Image, display

display(Image(filename='Final AI Project Images/first-attempt-wealthy-businessman-ditl.jpg'))

# %% [markdown]
# Refined Prompt(s):
#
# “Generate a short, historically accurate day in the life, styled diary entry of a 19th century, wealthy businessman travelling through Nice in 1867. Please make clear his freedoms as a male traveller, his class social status and the observations he makes. Also maintain a reflective tone of a 19th century traveller with considerations that the text will be for a non-specialist audience.”
#
# “Generate a short, historically accurate day in the life, styled diary entry of a 19th century, wealthy businessman travelling through Nice in 1867. Please make clear his freedoms as a male traveller, his class social status and the observations he makes. Also maintain a reflective tone of a 19th century traveller with considerations that the text will be for a non-specialist audience. Discuss topics like his accommodation, his travel by boat and rail and his daily activities.”
#
# Final Output:

# %%
from IPython.display import Image, display

display(Image(filename='Final AI Project Images/wealthy-businessman-ditl.jpg'))

# %% [markdown]
# The same approach was taken for the profile images but due to realsiing the need for specific descriptors, the initial outputs were generally suitable for the project.
#
# Initial Prompt:
#
# "Generate a realistic nineteenth-century traveller standing on a steamship deck travelling to France in 1867, wearing formal Victorian clothing, carrying luggage, overcast skies, inspired by archival sketchbook illustrations, but in a realistic style, not a line drawing, muted colour palette, historically accurate style.”

# %%
from IPython.display import Image, display

display(Image(filename='Final AI Project Images/wealthy-businessman-image.png'))

# %% [markdown]
# **Wealthy Businessman's Wife Profile**
#
# Below is the initial prompt and the refinements, as well as the final text output generated for the wealthy businessman's wife character.
#
# Initial Prompt:
#
# “Generate a short, historically accurate day in the life, styled diary entry of the 19th century, wealthy businessman’s wife travelling through France in 1867”
#
# Initial Output:

# %%
from IPython.display import Image, display

display(Image(filename='Final AI Project Images/first-attempt-wealthy-wife-ditl.jpg'))

# %% [markdown]
# Refined Prompt(s):
#
# “Generate a short, historically accurate day in the life, styled diary entry of a 19th century, wealthy businessman's wife travelling through Nice in 1867. Please make clear her limitation as a female traveller, class social status and expectations placed on her, and the observations she makes. Also maintain a reflective tone of a 19th century traveller with considerations that the text will be for a non-specialist audience. Discuss topics like his accommodation, her luggage and travel by boat and rail and her daily activities"
#
# Final Output:

# %%
from IPython.display import Image, display

display(Image(filename='Final AI Project Images/wealthy-wife-ditl.jpg'))

# %% [markdown]
# Again, a similar approach was taken for the image generation, with a carefully developed initial prompt used.
#
# Initial Prompt:
#
# "Generate a photorealistic nineteenth-century female traveller standing on a steamship deck travelling to France in 1867, wearing formal Victorian clothing, carrying luggage. There should be overcast skies, inspired by archival journal sketched illustrations, but in a realistic style, not a line drawing, muted colour palette, historically accurate style.”

# %%
from IPython.display import Image, display

display(Image(filename='Final AI Project Images/wealthy-businessmans-wife-image.png'))
