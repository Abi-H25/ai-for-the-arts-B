# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# **Test Markdown**
#
# - This the the test file for seeting up my week 1 repository and codespace for the AI for AH B course.
#
# - The above code prints the statement: "Hello World" and tests that my repository has Jupyter Notebooks installed
