# %% [markdown]
# **Introduction**
#
# This project explores how human and AI collaboration can be applied to a historical travel journal to convey different perspectives to a modern audience. By combining generative AI storytelling with the 19th century Journal of a Continental Tour, this project will focus on who travelled and why and highlight the social and cultural as well as some economic realities of travel during this time.
#
# Through using AI to transform the Journal into a more accessible and engaging format, the project aims to increase the overall understanding of historical travel and the potential demographics of users who can gain historical context and knowledge from it.

# %% [markdown]
# **Object Background**
#
# The object chosen for this from the University of Glasgow archive is the Journal of Continental Tour (GB 247 MS Gen 13). The journal was created between 1867 and 1868 by Andrew Macgeorge and documents his travels through particularly the south of France.
#
# The journal contains an array of written observations, hand drawn images, early photographs in addition to other interesting artefacts that all reflect the different areas of the journey through France.
#
# As the primary source for this project, the journal provides an interesting perspective of travel during a time when tourism was largely limited to those of higher social status. The details surrounding practical realities of travel and the attitudes of travellers make the journal valuable for further exploration and enhancement by collaborating with AI by being a detailed historical account of the journey around France.

# %% [markdown]
# **Project Aim and Approach**

# %% [markdown]
# **Audience**

# %%
from IPython.display import Image, display
display(Image(""))
